# %%
# !git clone https://github.com/javierDDT/CHallenge2-datascience-etl.git
# Out:
# Cloning into 'CHallenge2-datascience-etl'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 205.95 KiB | 6.06 MiB/s, done.

# %%
import json

# %%
data = json.load(open('/content/CHallenge2-datascience-etl/challenge2-data-science-LATAM-main/TelecomX_Data.json'))

# %%
# prompt: Para comenzar, realiza un análisis descriptivo de los datos, calculando métricas como media, mediana, desviación estándar y otras medidas que ayuden a comprender mejor la distribución y el comportamiento de los clientes.
# 📌 Consejos:
# 🔗 Documentación de DataFrame.describe()

import pandas as pd

# Convert the data to a pandas DataFrame
df = pd.DataFrame(data)

# Perform descriptive analysis
descriptive_stats = df.describe()

# Print the descriptive statistics
descriptive_stats
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %%
df.head(2)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
# prompt: for df need to unnest the dictionaries in customer, phone, internet and account columns

customer_df = pd.json_normalize(df['customer'])
phone_df = pd.json_normalize(df['phone'])
internet_df = pd.json_normalize(df['internet'])
account_df = pd.json_normalize(df['account'])

# Concatenate the new dataframes with the original one and drop the original nested columns
df = pd.concat([df, customer_df, phone_df, internet_df, account_df], axis=1).drop(columns=['customer', 'phone', 'internet', 'account'])

df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
# prompt: expand disctionary within a column is a dataframe, eval() arg 1 must be a string, bytes or code object, avoid that error

#import json
#import pandas as pd
# Assuming you have already cloned the repository and loaded the data as shown in the preceding code
# !git clone https://github.com/javierDDT/CHallenge2-datascience-etl.git
# data = json.load(open('/content/CHallenge2-datascience-etl/challenge2-data-science-LATAM-main/TelecomX_Data.json'))
# df = pd.DataFrame(data)

def safe_loads(x):
  try:
    return json.loads(x)
  except (json.JSONDecodeError, TypeError):
    # Return an empty dictionary or a dictionary with default values
    # depending on how you want to handle invalid data
    return {}

customer_expanded = df['customer'].apply(safe_loads).apply(pd.Series)
account_expanded = df['account'].apply(safe_loads).apply(pd.Series)
phone_expanded = df['phone'].apply(safe_loads).apply(pd.Series)
internet_expanded = df['internet'].apply(safe_loads).apply(pd.Series)

# %%
customer_expanded.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# prompt: En este paso, el objetivo es comprender cómo está distribuida la variable "churn" (evasión) entre los clientes. Utiliza gráficos para visualizar la proporción de clientes que permanecieron y los que se dieron de baja.

import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the distribution of the 'churn' variable
plt.figure(figsize=(6, 4))
sns.countplot(x='Churn', data=df)
plt.title('Distribution of Churn')
plt.xlabel('Churn')
plt.ylabel('Number of Customers')
plt.show()

# Visualize the proportion of churn
churn_counts = df['Churn'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Proportion of Churn')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# prompt: Ahora, exploraremos cómo se distribuye la evasión según variables categóricas, como género, tipo de contrato, método de pago, entre otras.
# Este análisis puede revelar patrones interesantes, por ejemplo, si los clientes de ciertos perfiles tienen una mayor tendencia a cancelar el servicio, lo que ayudará a orientar acciones estratégicas.

import matplotlib.pyplot as plt
# Analyze churn distribution by categorical variables
categorical_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                    'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                    'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
                    'PaperlessBilling', 'PaymentMethod']

for col in categorical_cols:
    plt.figure(figsize=(8, 5))
    sns.countplot(x=col, hue='Churn', data=df)
    plt.title(f'Churn Distribution by {col}')
    plt.xlabel(col)
    plt.ylabel('Number of Customers')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
# prompt: Ahora, exploraremos cómo se distribuye la evasión según variables categóricas, como género, tipo de contrato, método de pago, entre otras.
# Este análisis puede revelar patrones interesantes, por ejemplo, si los clientes de ciertos perfiles tienen una mayor tendencia a cancelar el servicio, lo que ayudará a orientar acciones estratégicas.

import matplotlib.pyplot as plt
# Visualize churn distribution by gender
plt.figure(figsize=(8, 5))
sns.countplot(x='gender', hue='Churn', data=df)
plt.title('Churn Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.show()

# Visualize churn distribution by contract type
plt.figure(figsize=(8, 5))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title('Churn Distribution by Contract Type')
plt.xlabel('Contract Type')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Visualize churn distribution by payment method
plt.figure(figsize=(10, 6))
sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.title('Churn Distribution by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Analyze the distribution of numerical variables for churned and non-churned customers

numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges'] # Assuming these are the numerical columns

for col in numerical_cols:
  plt.figure(figsize=(10, 6))
  sns.histplot(data=df, x=col, hue='Churn', kde=True, common_norm=False)
  plt.title(f'Distribution of {col} by Churn')
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0145eb2869ea> in <cell line: 0>()
#       5 for col in numerical_cols:
#       6   plt.figure(figsize=(10, 6))
# ----> 7   sns.histplot(data=df, x=col, hue='Churn', kde=True, common_norm=False)
#       8   plt.title(f'Distribution of {col} by Churn')
#       9   plt.xlabel(col)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1377 ):
#    1378
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#
# ...
